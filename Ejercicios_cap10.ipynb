# %% [markdown]
# # Ejercicio capitulo 10

# %% [markdown]
# ejercicio  1
#
# Revisa el programa anterior de este modo: Lee y analiza
# las líneas “From” y extrae las direcciones de correo. Cuenta el número
# de mensajes de cada persona utilizando un diccionario.
# Después de que todos los datos hayan sido leídos, imprime la persona con
# más envíos, creando una lista de tuplas (contador, email) del diccionario.
# Después ordena la lista en orden inverso e imprime la persona que tiene
# más envíos.

# %%
frecuencia=dict()

while True:
    narchivo = input("escribe el nombre del archivo ")

    try:
        if narchivo == "fin":
            break
        archivo = open(narchivo)
        print("el archivo fue abieto con exito\n ")
        for linea in archivo:
            linea = linea.rstrip() 
            
            if linea.startswith("From "):
                
              
                words = linea.split()
                
                if words[1]not in frecuencia:
                    frecuencia[words[1]]=1
                else:
                    frecuencia[words[1]]+=1
        
        
        lst=list()
        for clave, valor in list(frecuencia.items()):
            lst.append((valor,clave))
        lst.sort(reverse=True)
        for clave, valor in lst[:1]:
            print ( valor,clave )
            
        
        
        
        
        
        
        break 
    except:
        print("no es posible abrir el archivo")
# Out:
# el archivo fue abieto con exito
#
# zqian@umich.edu 195

# %% [markdown]
# Ejercicio 2: Este programa cuenta la distribución de la hora del día
# para cada uno de los mensajes. Puedes extraer la hora de la línea
# “From” buscando la cadena horaria y luego dividiendo la cadena en
# partes utilizando el carácter colon. Una vez que hayas acumulado las
# cuentas para cada hora, imprime las cuentas, una por línea, ordenadas
# por hora tal como se muestra debajo.

# %%
frecuencia=dict()

while True:
    narchivo = input("escribe el nombre del archivo ")

    try:
        if narchivo == "fin":
            break
        archivo = open(narchivo)
        print("el archivo fue abieto con exito\n ")
        for linea in archivo:
            linea = linea.rstrip() 
            
            if linea.startswith("From "):
                
              
                words = linea.split()

                #print(words[5])
                hora=words[5]
                hora2=hora[:2]
                #print(hora2)

                

                
                if hora2 not in frecuencia:
                    frecuencia[hora2]=1
                else:
                    frecuencia[hora2]+=1
        
        #print(frecuencia)
        lst=list()
        for clave, valor in list(frecuencia.items()):
            lst.append((clave,valor))
        lst.sort()
        for clave, valor in lst:
            print ( clave,valor )
            
        
        
        
        
        
        
        break 
    except:
        print("no es posible abrir el archivo")
# Out:
# el archivo fue abieto con exito
#
# 04 3
# 06 1
# 07 1
# 09 2
# 10 3
# 11 6
# 14 1
# 15 2
# 16 4
# 17 2
# 18 1
# 19 1

# %% [markdown]
# Ejercicio 3: Escribe un programa que lee un archivo e imprime las
# letras en order decreciente de frecuencia. El programa debe convertir
# todas las entradas a minúsculas y contar solamente las letras a-z.
# El programa no debe contar espacios, dígitos, signos de puntuación,
# o cualquier cosa que no sean las letras a-z. Encuentra ejemplos de
# texto en idiomas diferentes, y observa cómo la frecuencia de letras es
# diferente en cada idioma. Compara tus resultados con las tablas en

# %%
import string
string.punctuation

frecuencia=dict()
numeros=["1","2","3","4","5","6","7","8","9","0"]

while True:
    narchivo = input("escribe el nombre del archivo ")

    try:
        if narchivo == "fin":
            break
        archivo = open(narchivo)
        print("el archivo fue abieto con exito\n ")
        for linea in archivo:
            linea = linea.rstrip()

            linea=linea.translate(linea.maketrans("","",string.punctuation)) 

            linea=linea.lower()    

            words = linea.split()
            for palabra in words:
                lista_car=list(palabra)
                for caracter in lista_car:
                    if caracter in numeros:
                        continue
                    if caracter not in frecuencia:
                        frecuencia[caracter]=1
                    else:
                        frecuencia[caracter]+=1
        
        #print(frecuencia)
        lst=list()
        for clave, valor in list(frecuencia.items()):
            lst.append((valor,clave))
        lst.sort(reverse=True)
        for valor, clave in lst:
            print ( clave,valor )
            
        
        
        
        
        
        
        break 
    except:
        print("no es posible abrir el archivo")
# Out:
# el archivo fue abieto con exito
#
# i 14
# t 12
# e 12
# s 11
# a 11
# n 9
# h 9
# o 8
# r 7
# u 6
# l 6
# d 6
# w 5
# k 3
# g 3
# f 3
# y 2
# b 2
# v 1
# p 1
# m 1
# j 1
# c 1
